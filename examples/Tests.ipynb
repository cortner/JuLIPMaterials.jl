# %%
using PyPlot, JuLIP
import MaterialsScienceTools

# %%
reload("MaterialsScienceTools")
MST = MaterialsScienceTools
# Out:
# WARNING: replacing module MaterialsScienceTools
# WARNING: Method definition broadcast(Any, AbstractArray{T, N} where N, T, Any) in module MaterialsScienceTools at /Users/ortner/.julia/v0.6/MaterialsScienceTools/src/common.jl:11 overwritten in module MaterialsScienceTools at /Users/ortner/.julia/v0.6/MaterialsScienceTools/src/common.jl:11.
# MaterialsScienceTools

# %%
at = MST.cluster("Fe", 10.0; dims = [1,2])
@show pbc(at)
@show cell(at)
x, y, _ = xyz(at)
plot(x, y, "b.");
# Out:
# pbc(at) = Bool[false, false, true]
# cell(at) =
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x152ac2c50>)
# [40.18 0.0 0.0; 0.0 40.18 0.0; 0.0 0.0 2.87]

# %%
at = MST.cluster("Si", 10.0; dims = [1,2])
@show pbc(at)
@show cell(at)
x, y, _ = xyz(at)
plot(x, y, "b.");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x152cd9a10>)
# pbc(at) = Bool[false, false, true]
# cell(at) = [54.3 0.0 0.0; 0.0 54.3 0.0; 0.0 0.0 5.43]
